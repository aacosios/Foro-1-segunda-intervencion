# %% [markdown]
# # Universidad de las Fuerzas Armadas
# ## Foro Académico (Segunda Participacion)
#
# ### Andrés Cosios Pineda
#
# ### He tomado el ejercicio propuesto por el compañero Bryan Cardenas:
#
# $$f(x) = 3x^2+cos(2x)$$
#
# ## Graficamos la función

# %%
#Imprtamos las librerias necesarias para realizar los ejercicios de la actividad previamente las instalamos en python
import matplotlib.pyplot as plt
import math
import numpy as np
from scipy import linalg
from math import pi

# %%
# indicamos el estilo y función que vamos a usar para graficar
plt.style.use('seaborn')
# %matplotlib notebook

# %%
## Creamos el sitema lineal para graficar los elementos
x = np.linspace(-1,1,40)
# definimos las funciones que vamos a graficar
def f(x):
    return 3*x**3+np.cos(2*x)

# %%
# Generamos la grafica dentro del plano cartesiano y los arreglos visuales que necesitemos como ejes y colores
fig, ax = plt.subplots()
ax.plot(x,f(x))
xmin, xmax = ax.get_xlim()
ymin, ymax = ax.get_ylim()
ax.grid(True, linestyle='-')
ax.annotate("", xy=(xmax, 0), xytext=(xmin, 0),
           arrowprops=dict(color='gray', width=1.5, headwidth=8, headlength=10))
ax.annotate("", xy=(0, ymax), xytext=(0, ymin),
           arrowprops=dict(color='gray', width=1.5, headwidth=8, headlength=10))
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">

# %% [markdown]
# ## Primer Método:
# ### Método de la Bisección
#
# ### Consiste en partir de un intervalo, $[x_0,x_1]$ tal que $f(x_0) f(x_1) <0$,   por lo que sabemos que existe, al menos, una raíz real. A partir de este punto se va reduciendo el intervalo sucesivamente hasta hacerlo tan pequeño como exija la precisión que hayamos decidido emplear.

# %%
print('Implementación del metodo de la Bisección\n')
def biseccion (x0, x1, e):
    paso = 1
    condicion = True
    while condicion:
        x2=(x0+x1)/2
        print('Interaccion-%d, x2=%0.6f y f(x2)=%0.6f'% (paso, x2, f(x2)))
        if f(x0)*f(x2)<0:
            x1=x2
        else:
            x0=x2
        paso=paso+1
        condicion = abs(f(x2))>e
    print('\nLa raiz es: %0.8f'% x2)
    
x0=-1
x1=0
e=0.00001

x0= float(x0)
x1=float(x1)
e=float(e)

if f(x0)* f(x1)>0.0:
    print("los valores dados no incluyen la raiz")
else:
    biseccion(x0, x1, e)
# Out:
# Implementación del metodo de la Bisección
#
# Interaccion-1, x2=-0.500000 y f(x2)=0.165302
# Interaccion-2, x2=-0.750000 y f(x2)=-1.194888
# Interaccion-3, x2=-0.625000 y f(x2)=-0.417100
# Interaccion-4, x2=-0.562500 y f(x2)=-0.102759
# Interaccion-5, x2=-0.531250 y f(x2)=0.036891
# Interaccion-6, x2=-0.546875 y f(x2)=-0.031508
# Interaccion-7, x2=-0.539062 y f(x2)=0.003045
# Interaccion-8, x2=-0.542969 y f(x2)=-0.014143
# Interaccion-9, x2=-0.541016 y f(x2)=-0.005527
# Interaccion-10, x2=-0.540039 y f(x2)=-0.001235
# Interaccion-11, x2=-0.539551 y f(x2)=0.000907
# Interaccion-12, x2=-0.539795 y f(x2)=-0.000164
# Interaccion-13, x2=-0.539673 y f(x2)=0.000371
# Interaccion-14, x2=-0.539734 y f(x2)=0.000104
# Interaccion-15, x2=-0.539764 y f(x2)=-0.000030
# Interaccion-16, x2=-0.539749 y f(x2)=0.000037
# Interaccion-17, x2=-0.539757 y f(x2)=0.000003
#
# La raiz es: -0.53975677

# %% [markdown]
# ## Segundo Método:
# ### Método de la Regla Falsa
#
# ### El método de regla falsa, también conocido como regula falsi, es un método iterativo que a diferencia de bisección, que busca el punto medio del intervalo, une por medio de una línea recta las imágenes de la función en los dos extremos del intervalo $ (f(a) y f(b))$. La intersección de esta nueva recta con el eje x representa una mejor estimación de la raíz de la función. La función en el intervalo hallado por método de búsquedas debe ser continua y cumplir que $f(a) × f(b) < 0$.

# %%
print ('implemntacion del metodo de la regla falsa\n')
a=-1
b=0

m=(f(b)-f(a))/(b-a)
c=a-f(a)/m

while abs(f(c))>0.01:
    if f(c)*f(a)>0:
        a=c
    else:
        b=c
    m=(f(b)-f(a))/(b-a)
    c=a-f(a)/m
    
print(c, ' ', f(c))
print('La raiz es: ', c)
print('hola')
# Out:
# implemntacion del metodo de la regla falsa
#
# -0.5376092104404819   0.009394761004961394
# La raiz es:  -0.5376092104404819
# hola

# %% [markdown]
# ## Comparación de Resultados
#
# ### Mediante el metodo de la biseccion
#
# ### Mediante el método de la bisección hemos obtenido el siguiente resultado: - 0.53975677 Mientras que con el método de la regla falsa obtenemos la raíz: -0.5376092104404819
# ### El método de la bisección puede resultar más largo ya que requiere de varias interacciones para determinar la raíz, pero a su vez resulta más simple de implementar.
#
# ### Mientras que el método de la regla falsa es un método mucho más rápido y su resultado se obtendrá en menor tiempo.
#
# ### Por tanto, obtenemos resultados cercanos para lo cual vamos a realizar el cálculo de error
# ## Calculo del error
# ### Si graficamos la función en Geogebra nos da una raíz de : -0.5397575433659 que para nuestros fines lo tomaremos como el valor real (x) y como valor aproximado el valor calculado por nuestro programa: -0.53975677 $ (\tilde{x})$
#
# ## En el método de la bisección:
# ## Error absoluto
#
# ### $e_{abs}=|-0.5397575433659 -(-0.53975677)|$
# ### $e_{abs}= 0.00000077336$
#
# ## Error Relativo
#
# ### $e_{rel}=\frac{|-0.5397575433659 -(-0.53975677)|}{-0.5397575433659}$
# ### $e_{rel}= 0.0000014328$
#
# ## Error Porcentual
#
# ### $ e_{por} =0.0000014328 * 100$
# ### $e_{por} = 0.00014328 %$
#
# ## En el método de la regla falsa:
# ## Error absoluto
#
# ### $e_{abs}=|-0.5397575433659 -(-0.5376092104404819)|$
# ### $e_{abs}= 0.00214833292$
#
# ## Error Relativo
#
# ### $e_{rel}=\frac{|-0.5397575433659 -(-0.5376092104404819)|}{-0.5397575433659}$
# ### $e_{rel}= 0.00398018138$
#
# ## Error Porcentual
#
# ### $ e_{por} =0.0000014328 * 100$
# ### $e_{por} = 0.398018138 %$
#
# ## Conclución:
#
# ### Podemos concluir que los dos métodos nos dan resultados muy aproximados pero al calcular el porcentaje de error podemos observar que en este caso el método de la bisección no arroja un resultado mas aproximado al real por lo cual nos generaría mas confianza por lo cual en comparación entre el método de la bisección y de la regla falsa obtendríamos una mayor confianza con el método de la bisección.
